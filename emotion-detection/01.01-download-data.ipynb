# %% [markdown]
# ### Download RAVDESS dataset and create a csv file with metadata
#
# Source: [The Ryerson Audio-Visual Database of Emotional Speech and Song (RAVDESS)](https://zenodo.org/record/1188976)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import librosa
import librosa.display

# %% [markdown]
# ## Download data

# %%
# !rm -rf data
# !mkdir data
# !wget https://zenodo.org/record/1188976/files/Audio_Speech_Actors_01-24.zip\?download\=1 -O data/audio_speech.zip

# !cd data; unzip audio_speech.zip
# Out:
# --2020-06-09 12:29:49--  https://zenodo.org/record/1188976/files/Audio_Speech_Actors_01-24.zip?download=1
# Resolving zenodo.org (zenodo.org)... 188.184.117.155
# Connecting to zenodo.org (zenodo.org)|188.184.117.155|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 208468073 (199M) [application/octet-stream]
# Saving to: 'data/audio_speech.zip'
#
# data/audio_speech.z 100%[===================>] 198.81M  5.01MB/s    in 52s
#
# 2020-06-09 12:30:42 (3.84 MB/s) - 'data/audio_speech.zip' saved [208468073/208468073]
#
# Archive:  audio_speech.zip
#    creating: Actor_01/
#   inflating: Actor_01/03-01-01-01-01-01-01.wav
#   inflating: Actor_01/03-01-01-01-01-02-01.wav
#   inflating: Actor_01/03-01-01-01-02-01-01.wav
#   inflating: Actor_01/03-01-01-01-02-02-01.wav
#   inflating: Actor_01/03-01-02-01-01-01-01.wav
#   inflating: Actor_01/03-01-02-01-01-02-01.wav
#   inflating: Actor_01/03-01-02-01-02-01-01.wav
#   inflating: Actor_01/03-01-02-01-02-02-01.wav
# ...

# %% [markdown]
# ## Extract metadata

# %% [markdown]
# **File naming convention**
#
# Each of the 7356 RAVDESS files has a unique filename. The filename consists of a 7-part numerical identifier (e.g., 02-01-06-01-02-01-12.mp4). These identifiers define the stimulus characteristics:
#
# **Filename identifiers***
#
# * Modality (01 = full-AV, 02 = video-only, 03 = audio-only).
# * Vocal channel (01 = speech, 02 = song).
# * Emotion (01 = neutral, 02 = calm, 03 = happy, 04 = sad, 05 = angry, 06 = fearful, 07 = disgust, 08 = surprised).
# * Emotional intensity (01 = normal, 02 = strong). NOTE: There is no strong intensity for the 'neutral' emotion.
# * Statement (01 = "Kids are talking by the door", 02 = "Dogs are sitting by the door").
# * Repetition (01 = 1st repetition, 02 = 2nd repetition).
# * Actor (01 to 24. Odd numbered actors are male, even numbered actors are female).
#
# **Filename example**
#
# *02-01-06-01-02-01-12.mp4*
#
# 1. Video-only (02)
# 2. Speech (01)
# 3. Fearful (06)
# 4. Normal intensity (01)
# 5. Statement "dogs" (02)
# 6. 1st Repetition (01)
# 7. 12th Actor (12)
# 8. Female, as the actor ID number is even.

# %%
import re

_emotions_map = {
    '01': 'neutral',
    '02': 'calm',
    '03': 'happy',
    '04': 'sad',
    '05': 'angry',
    '06': 'fearful',
    '07': 'disgust',
    '08': 'surprised'
}

_intensity_map = {
    '01': 'normal',
    '02': 'strong'
}

def parse_name(file_name):
    match = re.search('(Actor_[0-9]*)/([0-9\-]*).wav$', file_name)
    actor_name = match.group(1)

    items = match.group(2).split('-')
    
    (_, _, emotion, intensity, statement, repetition, actor) = items
    
    return {
        'emotion': _emotions_map[emotion],
        'intensity': _intensity_map[intensity],
        'statement': statement,
        'repetition': repetition,
        'actor': 'female' if int(actor) % 2 else 'male',
        'actor_name': actor_name.lower(),
        'file_name': file_name
    }

# test
parse_name('data/Actor_01/03-01-01-01-01-01-01.wav')
# Out:
# {'emotion': 'neutral',
#  'intensity': 'normal',
#  'statement': '01',
#  'repetition': '01',
#  'actor': 'female',
#  'actor_name': 'actor_01',
#  'file_name': 'data/Actor_01/03-01-01-01-01-01-01.wav'}

# %%
from pathlib import Path
import pandas as pd

meta_data = []
for file_name in Path('data').glob('*/*.wav'):
    file_meta = parse_name(str(file_name))
    meta_data.append(file_meta)
    
meta_data = pd.DataFrame(meta_data)
meta_data.head()
# Out:
#    emotion intensity statement repetition actor actor_name  \
# 0    angry    normal        02         01  male   actor_16
# 1  fearful    normal        02         02  male   actor_16
# 2  fearful    strong        01         02  male   actor_16
# 3    angry    strong        01         01  male   actor_16
# 4  disgust    normal        01         01  male   actor_16
#
#                                 file_name
# 0  data/Actor_16/03-01-05-01-02-01-16.wav
# 1  data/Actor_16/03-01-06-01-02-02-16.wav
# 2  data/Actor_16/03-01-06-02-01-02-16.wav
# 3  data/Actor_16/03-01-05-02-01-01-16.wav
# 4  data/Actor_16/03-01-07-01-01-01-16.wav

# %%
meta_data.to_csv('meta_data.csv', index=False)

# %% [markdown]
# ## Plot examples

# %%
np.random.seed(5649)

audios = []
for i, item in enumerate(meta_data.sample(3).itertuples()):
    audio, sr = librosa.load(item.file_name)
    audios.append(audio)

# waveplots
fig, axes = plt.subplots(1, len(audios), sharex=True,
                         sharey=True, figsize=(15, 5))
for au, ax in zip(audios, axes):
    librosa.display.waveplot(au, ax=ax)

# plot mel histograms
fig, axes = plt.subplots(1, len(audios), sharex=False,
                         sharey=True, figsize=(15, 5))
for au, ax in zip(audios, axes):
    mel_spect = librosa.feature.melspectrogram(y=au)
    mel_spect = librosa.power_to_db(mel_spect, ref=np.max)
    
    librosa.display.specshow(mel_spect, y_axis='mel', x_axis='time', ax=ax)
